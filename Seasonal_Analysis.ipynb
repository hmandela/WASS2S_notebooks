# %%
from wass2s import *
import datetime
import importlib
from pathlib import Path
import warnings
import gc
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Set forecast working directory

# %%
# Set forecast working directory
dir_s2s = "./PRCP_MAM_2025_ic_1/"

# %%
dir_s2s = Path(dir_s2s)
os.makedirs(dir_s2s, exist_ok=True)

# %% [markdown]
# #### Set Climatological Years

# %%
# Set Climatological Years
clim_year_start = 1991 #1991
clim_year_end = 2020 #2020

# %% [markdown]
# #### Set Date for analysis

# %%
target_date = "2026-02-19"

# %% [markdown]
# ## Climate drivers evolution

# %% [markdown]
# #### Evolution from Six Previous to (target date)

# %%
main_driver(f"{dir_s2s}/Analysis", clim_year_start, clim_year_end, target_date, None)
# Out:
#  Traitement: SST
#  Data found: era5_sst_1991-2020_past5_40_-180_-40_180.nc
# Generating Monthly Maps for sst...
#  Traitement: SLP
#  Data found: era5_slp_1991-2020_past5_45_-60_-45_120.nc
# Generating Monthly Maps for slp...
#  Traitement: OLR
#  Data found: era5_olr_1991-2020_past5_40_-180_-40_180.nc
# Generating Monthly Maps for olr...
# Generating Hovmöller for olr...
#  Traitement: PRECIP
#  Data found: era5_precip_1991-2020_past5_35_-25_-5_55.nc
# Generating Monthly Maps for precip...
#  Traitement: WIND_850
#  Data found: era5_wind_850_1991-2020_past5_40_-60_-20_60.nc
# Generating Monthly Maps for wind_850...
#  Traitement: WIND_SURFACE
#  Data found: era5_wind_surface_1991-2020_past5_35_-30_-5_50.nc
# Generating Monthly Maps for wind_surface...
#  Finished.

# %% [markdown]
# #### Future Evolution from (target date)

# %%
# Initialize and display
viewer = C3SViewer()
viewer.show()
# Out:
# ...
# Output()

# %%
bom_widget = BOMViewer()
bom_widget.show()
